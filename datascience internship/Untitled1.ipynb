# %%
import seaborn as sns

# %% [markdown]
# **Joint plot**
#   * combines two different plots in one

# %%
sns.get_dataset_names()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# c:\users\dell\appdata\local\programs\python\python37\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# c:\users\dell\appdata\local\programs\python\python37\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1251         """Send a complete request to the server."""
# -> 1252         self._send_request(method, url, body, headers, encode_chunked)
#    1253
#
# c:\users\dell\appdata\local\programs\python\python37\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
# ...

# %%
iris= sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
sns.jointplot(x='sepal_length',y='sepal_width',data=iris,kind='reg')

# %%
import matplotlib.pyplot as plt
sns.jointplot(x="petal_length",y="petal_width",data=iris,kind="reg")
plt.show()

# %%
sns.jointplot(x="petal_length",y="petal_width",data=iris,)
plt.show()

# %%
help(sns.jointplot)
# Out:
# Help on function jointplot in module seaborn.axisgrid:
#
# jointplot(*, x=None, y=None, data=None, kind='scatter', color=None, height=6, ratio=5, space=0.2, dropna=False, xlim=None, ylim=None, marginal_ticks=False, joint_kws=None, marginal_kws=None, hue=None, palette=None, hue_order=None, hue_norm=None, **kwargs)
#     Draw a plot of two variables with bivariate and univariate graphs.
#
#     This function provides a convenient interface to the :class:`JointGrid`
#     class, with several canned plot kinds. This is intended to be a fairly
#     lightweight wrapper; if you need more flexibility, you should use
#     :class:`JointGrid` directly.
#
#     Parameters
#     ----------
#     x, y : vectors or keys in ``data``
#         Variables that specify positions on the x and y axes.
#     data : :class:`pandas.DataFrame`, :class:`numpy.ndarray`, mapping, or sequence
#         Input data structure. Either a long-form collection of vectors that can be
# ...

# %%
sns.jointplot(x="petal_length",y="petal_width",data=iris,kind="kde",color="m")
plt.show()

# %%
sns.jointplot(x="petal_length",y="petal_width",data=iris,kind="hex",color="g")

# %%
sns.jointplot(x="petal_length",y="petal_width",data=iris,color='k').plot_joint(sns.kdeplot,n_levels=10)
plt.show()

# %%
sns.set_style('ticks')
sns.pairplot(iris,hue="species",diag_kind="kde",kind="scatter",palette="husl")
plt.show()
